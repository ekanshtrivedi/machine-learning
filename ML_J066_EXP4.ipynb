# %% [markdown]
# <a href="https://colab.research.google.com/github/ekanshtrivedi/machine-learning/blob/master/ML_J066_EXP4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt #visualisation
import seaborn as sns #advanced visualisation
import matplotlib as mpl
 
df_can = pd.read_excel('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/Canada.xlsx',
 sheet_name='Canada by Citizenship',
 skiprows=range(20),
 skipfooter=2)
 
print('Data downloaded and read into a dataframe!')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Data downloaded and read into a dataframe!

# %%
df_can.head()
# Out:
#          Type    Coverage          OdName  AREA  ...  2010  2011  2012  2013
# 0  Immigrants  Foreigners     Afghanistan   935  ...  1758  2203  2635  2004
# 1  Immigrants  Foreigners         Albania   908  ...   561   539   620   603
# 2  Immigrants  Foreigners         Algeria   903  ...  4752  4325  3774  4331
# 3  Immigrants  Foreigners  American Samoa   909  ...     0     0     0     0
# 4  Immigrants  Foreigners         Andorra   908  ...     0     0     1     1
#
# [5 rows x 43 columns]

# %%
#preprocessing
df_can.drop(['AREA','REG','DEV','Type','Coverage'], inplace= True, axis = 'columns')

# %%
years = range(1980,2014)
df_can['Total'] = df_can.sum(axis = 'columns')
df_can.rename(columns = {"OdName":"Country","AreaName":"Continent","RegName":'Region'}, inplace = True)
df_can.set_index('Country', inplace= True)

# %%
df_continents = df_can.groupby('Continent', axis = 'index').sum()

# %%
df_continents.head()
# Out:
#                                   1980   1981   1982  ...    2012    2013    Total
# Continent                                             ...
# Africa                            3951   4363   3819  ...   38083   38543   618948
# Asia                             31025  34314  30214  ...  152218  155075  3317794
# Europe                           39760  44802  42720  ...   29177   28691  1410947
# Latin America and the Caribbean  13081  15215  16769  ...   27173   24950   765148
# Northern America                  9378  10030   9074  ...    7892    8503   241142
#
# [5 rows x 35 columns]

# %% [markdown]
# Q1. By Continent-region pie-chart use colorlists, explode, pct, figsize, add title, add axes, add legend, remove labels and use shadows.

# %%
explodelist = [0,0,0.2,0,0,0]
df_con_region = df_can.groupby("Region", axis='rows').sum()
df_con_region['Total'].plot(kind = 'pie', figsize = (10,10), autopct = '%1.1f%%', shadow = True, labels = None)
plt.title("Total immigrants from Canada")
plt.legend(labels = df_con_region.index, loc = 'upper right' )

# %% [markdown]
# Q2.By Development-status pie-chart use colorlists, explode, pct, figsize, add title, add axes, add legend, remove labels and use shadows

# %%
df_dev = df_can.groupby('DevName', axis = 'rows').sum()
df_dev['Total'].plot(kind = 'pie', figsize = (10,10), autopct = '%1.1f%%', shadow = True, labels = None)
plt.title("Total immigrants by Development Status")
plt.legend(labels = df_dev.index, loc = 'upper right' )

# %%
df_can.sort_values(by = 'Total', axis = 'index', inplace = True, ascending = False)
df_top5 = df_can.head(5)
df_top5 = df_top5[years]
df_top5 = df_top5.transpose()
df_top5.plot(kind = 'box', figsize = (10,10), vert = False)

# %%
df_can.sort_values(by = 'Total', axis = 'index', inplace = True, ascending = False)
df_bot5 = df_can.tail(5)
df_bot5 = df_bot5[years]
df_bot5 = df_bot5.transpose()
df_bot5.plot(kind = 'box', figsize = (10,10), vert = False)

# %%
#using subplots
fig = plt.figure()
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

df_top5.plot(kind = 'box', figsize = (10,10), vert = False, ax = ax1)

df_bot5.plot(kind = 'box', figsize = (10,10), vert = False, ax = ax2)

# %% [markdown]
# Q3. Create 4 subplots - to display boxplot of top 5 countries in europe, asia, africa, oceania

# %%
asia = df_can[df_can['Continent']=='Asia'].head(5)
asia = asia[years].transpose()
europe = df_can[df_can['Continent']=='Europe'].head(5)
europe = europe[years].transpose()
africa = df_can[df_can['Continent']=='Africa'].head(5)
africa = africa[years].transpose()
oceania = df_can[df_can['Continent']=='Oceania'].head(5)
oceania = oceania[years].transpose()
fig = plt.figure()

ax0 = fig.add_subplot(1,4,1)
ax1 = fig.add_subplot(1,4,2)
ax2 = fig.add_subplot(1,4,3)
ax3 = fig.add_subplot(1,4,4)

asia.plot(kind="box",figsize=(20,10),vert=False,color='blue', ax=ax0)
europe.plot(kind="box",figsize=(20,10),vert=False,color='red', ax=ax1)
africa.plot(kind="box",figsize=(20,10),vert=False,color='black', ax=ax1)
oceania.plot(kind="box",figsize=(20,10),vert=False,color='green', ax=ax1)

# %%
for country in df_can.index:
  df = df_can.loc[[country], years].transpose().describe()
  Q1 = df.loc['25%']
  Q3 = df.loc['75%']
  IQR=Q3-Q1
  Outlier1 = Q3+1.5*IQR
  Outlier2 = Q1 - 1.5*IQR
  print(Outlier1)
  print(Outlier2)
  print("----")
# Out:
# Country
# India    55792.125
# dtype: float64
# Country
# India   -16454.875
# dtype: float64
# ----
# Country
# China    70652.125
# dtype: float64
# Country
# China   -33570.875
# dtype: float64
# ----
# Country
# United Kingdom of Great Britain and Northern Ireland    47095.375
# dtype: float64
# Country
# United Kingdom of Great Britain and Northern Ireland   -15315.625
# dtype: float64
# ----
# Country
# Philippines    35128.0
# dtype: float64
# Country
# Philippines   -7216.0
# dtype: float64
# ----
# Country
# Pakistan    28298.875
# dtype: float64
# Country
# Pakistan   -14474.125
# dtype: float64
# ----
# Country
# United States of America    12313.5
# dtype: float64
# Country
# United States of America    1693.5
# dtype: float64
# ----
# Country
# Iran (Islamic Republic of)    12745.0
# dtype: float64
# Country
# Iran (Islamic Republic of)   -2751.0
# dtype: float64
# ----
# Country
# Sri Lanka    9307.625
# dtype: float64
# Country
# Sri Lanka   -1163.375
# dtype: float64
# ----
# Country
# Republic of Korea    11054.25
# dtype: float64
# Country
# Republic of Korea   -2787.75
# dtype: float64
# ----
# Country
# Poland    9923.125
# dtype: float64
# Country
# Poland   -3891.875
# dtype: float64
# ----
# Country
# Lebanon    6736.25
# dtype: float64
# Country
# Lebanon   -1431.75
# dtype: float64
# ----
# Country
# France    6870.0
# dtype: float64
# Country
# France   -622.0
# dtype: float64
# ----
# Country
# Jamaica    6112.375
# dtype: float64
# Country
# Jamaica    51.375
# dtype: float64
# ----
# Country
# Viet Nam    5713.125
# dtype: float64
# Country
# Viet Nam   -611.875
# dtype: float64
# ----
# Country
# Romania    8010.75
# dtype: float64
# Country
# Romania   -2759.25
# dtype: float64
# ----
# Country
# Haiti    4378.0
# dtype: float64
# Country
# Haiti    22.0
# dtype: float64
# ----
# Country
# Guyana    5502.375
# dtype: float64
# Country
# Guyana   -1254.625
# dtype: float64
# ----
# Country
# Portugal    5633.75
# dtype: float64
# Country
# Portugal   -2534.25
# dtype: float64
# ----
# Country
# Egypt    4624.5
# dtype: float64
# Country
# Egypt   -921.5
# dtype: float64
# ----
# Country
# Morocco    8017.5
# dtype: float64
# Country
# Morocco   -3744.5
# dtype: float64
# ----
# Country
# Colombia    9876.375
# dtype: float64
# Country
# Colombia   -5330.625
# dtype: float64
# ----
# Country
# Iraq    5601.875
# dtype: float64
# Country
# Iraq   -2445.125
# dtype: float64
# ----
# Country
# Algeria    8618.125
# dtype: float64
# Country
# Algeria   -4706.875
# dtype: float64
# ----
# Country
# Israel    4095.25
# dtype: float64
# Country
# Israel   -174.75
# dtype: float64
# ----
# Country
# Bangladesh    6585.875
# dtype: float64
# Country
# Bangladesh   -3167.125
# dtype: float64
# ----
# Country
# Germany    2999.875
# dtype: float64
# Country
# Germany    452.875
# dtype: float64
# ----
# Country
# Russian Federation    8900.625
# dtype: float64
# Country
# Russian Federation   -5340.375
# dtype: float64
# ----
# Country
# Mexico    5553.375
# dtype: float64
# Country
# Mexico   -2075.625
# dtype: float64
# ----
# Country
# Afghanistan    5393.375
# dtype: float64
# Country
# Afghanistan   -2015.625
# dtype: float64
# ----
# Country
# El Salvador    6055.25
# dtype: float64
# Country
# El Salvador   -2874.75
# dtype: float64
# ----
# Country
# Ukraine    6293.125
# dtype: float64
# Country
# Ukraine   -3775.875
# dtype: float64
# ----
# Country
# Trinidad and Tobago    3999.125
# dtype: float64
# Country
# Trinidad and Tobago   -1103.875
# dtype: float64
# ----
# Country
# Somalia    3508.625
# dtype: float64
# Country
# Somalia   -1684.375
# dtype: float64
# ----
# Country
# South Africa    2075.625
# dtype: float64
# Country
# South Africa    350.625
# dtype: float64
# ----
# Country
# Nigeria    4667.625
# dtype: float64
# Country
# Nigeria   -2549.375
# dtype: float64
# ----
# Country
# Jordan    2925.5
# dtype: float64
# Country
# Jordan   -854.5
# dtype: float64
# ----
# Country
# Ethiopia    2935.5
# dtype: float64
# Country
# Ethiopia   -814.5
# dtype: float64
# ----
# Country
# Peru    2483.0
# dtype: float64
# Country
# Peru   -515.0
# dtype: float64
# ----
# Country
# Turkey    2158.25
# dtype: float64
# Country
# Turkey   -257.75
# dtype: float64
# ----
# Country
# Syrian Arab Republic    1453.25
# dtype: float64
# Country
# Syrian Arab Republic    459.25
# dtype: float64
# ----
# Country
# Brazil    1962.0
# dtype: float64
# Country
# Brazil   -492.0
# dtype: float64
# ----
# Country
# Japan    1904.0
# dtype: float64
# Country
# Japan   -296.0
# dtype: float64
# ----
# Country
# Netherlands    1142.75
# dtype: float64
# Country
# Netherlands    290.75
# dtype: float64
# ----
# Country
# Ghana    1767.125
# dtype: float64
# Country
# Ghana   -365.875
# dtype: float64
# ----
# Country
# Democratic Republic of the Congo    3035.625
# dtype: float64
# Country
# Democratic Republic of the Congo   -1737.375
# dtype: float64
# ----
# Country
# Malaysia    1443.25
# dtype: float64
# Country
# Malaysia   -244.75
# dtype: float64
# ----
# Country
# Australia    1413.0
# dtype: float64
# Country
# Australia    1.0
# dtype: float64
# ----
# Country
# Bulgaria    2623.375
# dtype: float64
# Country
# Bulgaria   -1477.625
# dtype: float64
# ----
# Country
# Italy    1413.875
# dtype: float64
# Country
# Italy   -229.125
# dtype: float64
# ----
# Country
# Bosnia and Herzegovina    1772.5
# dtype: float64
# Country
# Bosnia and Herzegovina   -1063.5
# dtype: float64
# ----
# Country
# Chile    1818.625
# dtype: float64
# Country
# Chile   -530.375
# dtype: float64
# ----
# Country
# Venezuela (Bolivarian Republic of)    2112.125
# dtype: float64
# Country
# Venezuela (Bolivarian Republic of)   -810.875
# dtype: float64
# ----
# Country
# Fiji    1125.25
# dtype: float64
# Country
# Fiji   -98.75
# dtype: float64
# ----
# Country
# Cuba    2191.625
# dtype: float64
# Country
# Cuba   -1097.375
# dtype: float64
# ----
# Country
# Argentina    1138.25
# dtype: float64
# Country
# Argentina   -117.75
# dtype: float64
# ----
# Country
# Guatemala    1469.25
# dtype: float64
# Country
# Guatemala   -466.75
# dtype: float64
# ----
# Country
# Sudan    1664.75
# dtype: float64
# Country
# Sudan   -891.25
# dtype: float64
# ----
# Country
# Tunisia    1734.875
# dtype: float64
# Country
# Tunisia   -806.125
# dtype: float64
# ----
# Country
# Kenya    1165.125
# dtype: float64
# Country
# Kenya   -219.875
# dtype: float64
# ----
# Country
# Ireland    1414.875
# dtype: float64
# Country
# Ireland   -474.125
# dtype: float64
# ----
# Country
# Hungary    1047.0
# dtype: float64
# Country
# Hungary   -89.0
# dtype: float64
# ----
# Country
# Cameroon    1369.75
# dtype: float64
# Country
# Cameroon   -784.25
# dtype: float64
# ----
# Country
# Albania    1777.875
# dtype: float64
# Country
# Albania   -1063.125
# dtype: float64
# ----
# Country
# Mauritius    1136.0
# dtype: float64
# Country
# Mauritius   -360.0
# dtype: float64
# ----
# Country
# Switzerland    1017.625
# dtype: float64
# Country
# Switzerland   -115.375
# dtype: float64
# ----
# Country
# Republic of Moldova    1620.625
# dtype: float64
# Country
# Republic of Moldova   -972.375
# dtype: float64
# ----
# Country
# Singapore    840.0
# dtype: float64
# Country
# Singapore   -100.0
# dtype: float64
# ----
# Country
# Indonesia    1052.625
# dtype: float64
# Country
# Indonesia   -300.375
# dtype: float64
# ----
# Country
# United Republic of Tanzania    858.5
# dtype: float64
# Country
# United Republic of Tanzania   -167.5
# dtype: float64
# ----
# Country
# Greece    1261.125
# dtype: float64
# Country
# Greece   -565.875
# dtype: float64
# ----
# Country
# Ecuador    628.375
# dtype: float64
# Country
# Ecuador    69.375
# dtype: float64
# ----
# Country
# Nicaragua    906.375
# dtype: float64
# Country
# Nicaragua   -400.625
# dtype: float64
# ----
# Country
# Dominican Republic    737.625
# dtype: float64
# Country
# Dominican Republic   -65.375
# dtype: float64
# ----
# Country
# Belgium    547.5
# dtype: float64
# Country
# Belgium    55.5
# dtype: float64
# ----
# Country
# Eritrea    1248.75
# dtype: float64
# Country
# Eritrea   -749.25
# dtype: float64
# ----
# Country
# New Zealand    608.5
# dtype: float64
# Country
# New Zealand   -31.5
# dtype: float64
# ----
# Country
# Nepal    1191.125
# dtype: float64
# Country
# Nepal   -693.875
# dtype: float64
# ----
# Country
# Saint Vincent and the Grenadines    622.0
# dtype: float64
# Country
# Saint Vincent and the Grenadines   -68.0
# dtype: float64
# ----
# Country
# China, Hong Kong Special Administrative Region    1443.125
# dtype: float64
# Country
# China, Hong Kong Special Administrative Region   -865.875
# dtype: float64
# ----
# Country
# Myanmar    465.375
# dtype: float64
# Country
# Myanmar   -177.625
# dtype: float64
# ----
# Country
# Thailand    775.125
# dtype: float64
# Country
# Thailand   -227.875
# dtype: float64
# ----
# Country
# Grenada    611.625
# dtype: float64
# Country
# Grenada   -91.375
# dtype: float64
# ----
# Country
# Zimbabwe    1002.5
# dtype: float64
# Country
# Zimbabwe   -507.5
# dtype: float64
# ----
# Country
# Kazakhstan    1116.25
# dtype: float64
# Country
# Kazakhstan   -669.75
# dtype: float64
# ----
# Country
# Côte d'Ivoire    671.5
# dtype: float64
# Country
# Côte d'Ivoire   -360.5
# dtype: float64
# ----
# Country
# Burundi    1148.5
# dtype: float64
# Country
# Burundi   -679.5
# dtype: float64
# ----
# Country
# Croatia    895.0
# dtype: float64
# Country
# Croatia   -537.0
# dtype: float64
# ----
# Country
# Belarus    1093.125
# dtype: float64
# Country
# Belarus   -655.875
# dtype: float64
# ----
# Country
# Honduras    539.625
# dtype: float64
# Country
# Honduras   -137.375
# dtype: float64
# ----
# Country
# Senegal    622.875
# dtype: float64
# Country
# Senegal   -342.125
# dtype: float64
# ----
# Country
# Barbados    523.25
# dtype: float64
# Country
# Barbados   -118.75
# dtype: float64
# ----
# Country
# Rwanda    916.875
# dtype: float64
# Country
# Rwanda   -532.125
# dtype: float64
# ----
# Country
# Cambodia    676.0
# dtype: float64
# Country
# Cambodia   -360.0
# dtype: float64
# ----
# Country
# State of Palestine    985.0
# dtype: float64
# Country
# State of Palestine   -591.0
# dtype: float64
# ----
# Country
# Slovakia    599.375
# dtype: float64
# Country
# Slovakia   -359.625
# dtype: float64
# ----
# Country
# Bhutan    17.125
# dtype: float64
# Country
# Bhutan   -9.875
# dtype: float64
# ----
# Country
# Sweden    252.25
# dtype: float64
# Country
# Sweden    76.25
# dtype: float64
# ----
# Country
# Spain    290.5
# dtype: float64
# Country
# Spain   -23.5
# dtype: float64
# ----
# Country
# Austria    309.375
# dtype: float64
# Country
# Austria   -9.625
# dtype: float64
# ----
# Country
# Libya    443.125
# dtype: float64
# Country
# Libya   -179.875
# dtype: float64
# ----
# Country
# Guinea    668.125
# dtype: float64
# Country
# Guinea   -380.875
# dtype: float64
# ----
# Country
# Saint Lucia    312.25
# dtype: float64
# Country
# Saint Lucia   -55.75
# dtype: float64
# ----
# Country
# Uruguay    253.5
# dtype: float64
# Country
# Uruguay   -4.5
# dtype: float64
# ----
# Country
# The former Yugoslav Republic of Macedonia    519.375
# dtype: float64
# Country
# The former Yugoslav Republic of Macedonia   -311.625
# dtype: float64
# ----
# Country
# Costa Rica    305.625
# dtype: float64
# Country
# Costa Rica   -33.375
# dtype: float64
# ----
# Country
# Czech Republic    448.125
# dtype: float64
# Country
# Czech Republic   -268.875
# dtype: float64
# ----
# Country
# Denmark    155.25
# dtype: float64
# Country
# Denmark    37.25
# dtype: float64
# ----
# Country
# Togo    365.375
# dtype: float64
# Country
# Togo   -195.625
# dtype: float64
# ----
# Country
# Uganda    352.75
# dtype: float64
# Country
# Uganda   -141.25
# dtype: float64
# ----
# Country
# Saudi Arabia    396.875
# dtype: float64
# Country
# Saudi Arabia   -200.125
# dtype: float64
# ----
# Country
# Uzbekistan    414.375
# dtype: float64
# Country
# Uzbekistan   -248.625
# dtype: float64
# ----
# Country
# Sierra Leone    208.25
# dtype: float64
# Country
# Sierra Leone   -93.75
# dtype: float64
# ----
# Country
# Armenia    466.875
# dtype: float64
# Country
# Armenia   -280.125
# dtype: float64
# ----
# Country
# Bolivia (Plurinational State of)    243.5
# dtype: float64
# Country
# Bolivia (Plurinational State of)   -66.5
# dtype: float64
# ----
# Country
# Panama    146.125
# dtype: float64
# Country
# Panama   -50.875
# dtype: float64
# ----
# Country
# Yemen    331.625
# dtype: float64
# Country
# Yemen   -177.375
# dtype: float64
# ----
# Country
# Benin    249.875
# dtype: float64
# Country
# Benin   -129.125
# dtype: float64
# ----
# Country
# Finland    112.375
# dtype: float64
# Country
# Finland    33.375
# dtype: float64
# ----
# Country
# Liberia    170.5
# dtype: float64
# Country
# Liberia   -95.5
# dtype: float64
# ----
# Country
# Azerbaijan    388.125
# dtype: float64
# Country
# Azerbaijan   -232.875
# dtype: float64
# ----
# Country
# Dominica    114.0
# dtype: float64
# Country
# Dominica    26.0
# dtype: float64
# ----
# Country
# Lithuania    278.5
# dtype: float64
# Country
# Lithuania   -165.5
# dtype: float64
# ----
# Country
# Kyrgyzstan    330.625
# dtype: float64
# Country
# Kyrgyzstan   -198.375
# dtype: float64
# ----
# Country
# Norway    110.75
# dtype: float64
# Country
# Norway    20.75
# dtype: float64
# ----
# Country
# Latvia    270.25
# dtype: float64
# Country
# Latvia   -161.75
# dtype: float64
# ----
# Country
# Madagascar    169.375
# dtype: float64
# Country
# Madagascar   -53.625
# dtype: float64
# ----
# Country
# Mali    212.625
# dtype: float64
# Country
# Mali   -116.375
# dtype: float64
# ----
# Country
# Angola    165.25
# dtype: float64
# Country
# Angola   -88.75
# dtype: float64
# ----
# Country
# Georgia    309.375
# dtype: float64
# Country
# Georgia   -185.625
# dtype: float64
# ----
# Country
# Burkina Faso    232.0
# dtype: float64
# Country
# Burkina Faso   -132.0
# dtype: float64
# ----
# Country
# Kuwait    201.5
# dtype: float64
# Country
# Kuwait   -90.5
# dtype: float64
# ----
# Country
# Paraguay    132.75
# dtype: float64
# Country
# Paraguay   -21.25
# dtype: float64
# ----
# Country
# Serbia    0.0
# dtype: float64
# Country
# Serbia    0.0
# dtype: float64
# ----
# Country
# Congo    220.125
# dtype: float64
# Country
# Congo   -126.875
# dtype: float64
# ----
# Country
# Zambia    121.5
# dtype: float64
# Country
# Zambia   -18.5
# dtype: float64
# ----
# Country
# Chad    223.5
# dtype: float64
# Country
# Chad   -128.5
# dtype: float64
# ----
# Country
# Djibouti    165.875
# dtype: float64
# Country
# Djibouti   -91.125
# dtype: float64
# ----
# Country
# Malta    137.25
# dtype: float64
# Country
# Malta   -60.75
# dtype: float64
# ----
# Country
# Seychelles    44.875
# dtype: float64
# Country
# Seychelles   -14.125
# dtype: float64
# ----
# Country
# Cyprus    92.875
# dtype: float64
# Country
# Cyprus   -34.125
# dtype: float64
# ----
# Country
# Lao People's Democratic Republic    73.375
# dtype: float64
# Country
# Lao People's Democratic Republic   -11.625
# dtype: float64
# ----
# Country
# Belize    56.875
# dtype: float64
# Country
# Belize    5.875
# dtype: float64
# ----
# Country
# Mauritania    134.625
# dtype: float64
# Country
# Mauritania   -74.375
# dtype: float64
# ----
# Country
# Antigua and Barbuda    76.625
# dtype: float64
# Country
# Antigua and Barbuda   -18.375
# dtype: float64
# ----
# Country
# Mongolia    131.875
# dtype: float64
# Country
# Mongolia   -79.125
# dtype: float64
# ----
# Country
# Gabon    139.5
# dtype: float64
# Country
# Gabon   -78.5
# dtype: float64
# ----
# Country
# Niger    129.125
# dtype: float64
# Country
# Niger   -75.875
# dtype: float64
# ----
# Country
# Estonia    108.75
# dtype: float64
# Country
# Estonia   -65.25
# dtype: float64
# ----
# Country
# United Arab Emirates    84.25
# dtype: float64
# Country
# United Arab Emirates   -41.75
# dtype: float64
# ----
# Country
# Bahamas    43.875
# dtype: float64
# Country
# Bahamas    0.875
# dtype: float64
# ----
# Country
# Suriname    40.375
# dtype: float64
# Country
# Suriname   -4.625
# dtype: float64
# ----
# Country
# Saint Kitts and Nevis    44.125
# dtype: float64
# Country
# Saint Kitts and Nevis   -8.875
# dtype: float64
# ----
# Country
# Gambia    51.375
# dtype: float64
# Country
# Gambia   -19.625
# dtype: float64
# ----
# Country
# Brunei Darussalam    32.75
# dtype: float64
# Country
# Brunei Darussalam   -13.25
# dtype: float64
# ----
# Country
# Iceland    27.5
# dtype: float64
# Country
# Iceland   -0.5
# dtype: float64
# ----
# Country
# Central African Republic    40.125
# dtype: float64
# Country
# Central African Republic   -18.875
# dtype: float64
# ----
# Country
# Slovenia    59.375
# dtype: float64
# Country
# Slovenia   -35.625
# dtype: float64
# ----
# Country
# Tajikistan    46.875
# dtype: float64
# Country
# Tajikistan   -28.125
# dtype: float64
# ----
# Country
# Bahrain    39.875
# dtype: float64
# Country
# Bahrain   -13.125
# dtype: float64
# ----
# Country
# Botswana    18.875
# dtype: float64
# Country
# Botswana   -8.125
# dtype: float64
# ----
# Country
# Democratic People's Republic of Korea    31.625
# dtype: float64
# Country
# Democratic People's Republic of Korea   -17.375
# dtype: float64
# ----
# Country
# Namibia    21.375
# dtype: float64
# Country
# Namibia   -9.625
# dtype: float64
# ----
# Country
# Turkmenistan    38.75
# dtype: float64
# Country
# Turkmenistan   -23.25
# dtype: float64
# ----
# Country
# Malawi    23.0
# dtype: float64
# Country
# Malawi   -7.0
# dtype: float64
# ----
# Country
# China, Macao Special Administrative Region    49.375
# dtype: float64
# Country
# China, Macao Special Administrative Region   -29.625
# dtype: float64
# ----
# Country
# Oman    26.0
# dtype: float64
# Country
# Oman   -14.0
# dtype: float64
# ----
# Country
# Luxembourg    18.0
# dtype: float64
# Country
# Luxembourg   -6.0
# dtype: float64
# ----
# Country
# Cabo Verde    19.5
# dtype: float64
# Country
# Cabo Verde   -8.5
# dtype: float64
# ----
# Country
# Comoros    13.875
# dtype: float64
# Country
# Comoros   -5.125
# dtype: float64
# ----
# Country
# Swaziland    14.5
# dtype: float64
# Country
# Swaziland   -5.5
# dtype: float64
# ----
# Country
# Mozambique    12.375
# dtype: float64
# Country
# Mozambique   -2.625
# dtype: float64
# ----
# Country
# Qatar    13.5
# dtype: float64
# Country
# Qatar   -6.5
# dtype: float64
# ----
# Country
# Tonga    12.0
# dtype: float64
# Country
# Tonga   -4.0
# dtype: float64
# ----
# Country
# Lesotho    10.375
# dtype: float64
# Country
# Lesotho   -4.625
# dtype: float64
# ----
# Country
# Montenegro    0.0
# dtype: float64
# Country
# Montenegro    0.0
# dtype: float64
# ----
# Country
# Guinea-Bissau    10.0
# dtype: float64
# Country
# Guinea-Bissau   -6.0
# dtype: float64
# ----
# Country
# Samoa    6.0
# dtype: float64
# Country
# Samoa   -2.0
# dtype: float64
# ----
# Country
# Papua New Guinea    7.125
# dtype: float64
# Country
# Papua New Guinea   -3.875
# dtype: float64
# ----
# Country
# Equatorial Guinea    7.5
# dtype: float64
# Country
# Equatorial Guinea   -4.5
# dtype: float64
# ----
# Country
# Liechtenstein    5.0
# dtype: float64
# Country
# Liechtenstein   -3.0
# dtype: float64
# ----
# Country
# Maldives    2.5
# dtype: float64
# Country
# Maldives   -1.5
# dtype: float64
# ----
# Country
# Monaco    2.5
# dtype: float64
# Country
# Monaco   -1.5
# dtype: float64
# ----
# Country
# Canada    2.5
# dtype: float64
# Country
# Canada   -1.5
# dtype: float64
# ----
# Country
# Nauru    2.5
# dtype: float64
# Country
# Nauru   -1.5
# dtype: float64
# ----
# Country
# Andorra    2.5
# dtype: float64
# Country
# Andorra   -1.5
# dtype: float64
# ----
# Country
# Kiribati    2.5
# dtype: float64
# Country
# Kiribati   -1.5
# dtype: float64
# ----
# Country
# Vanuatu    0.0
# dtype: float64
# Country
# Vanuatu    0.0
# dtype: float64
# ----
# Country
# Sao Tome and Principe    0.0
# dtype: float64
# Country
# Sao Tome and Principe    0.0
# dtype: float64
# ----
# Country
# Tuvalu    0.0
# dtype: float64
# Country
# Tuvalu    0.0
# dtype: float64
# ----
# Country
# American Samoa    0.0
# dtype: float64
# Country
# American Samoa    0.0
# dtype: float64
# ----
# Country
# San Marino    0.0
# dtype: float64
# Country
# San Marino    0.0
# dtype: float64
# ----
# Country
# New Caledonia    0.0
# dtype: float64
# Country
# New Caledonia    0.0
# dtype: float64
# ----
# Country
# Marshall Islands    0.0
# dtype: float64
# Country
# Marshall Islands    0.0
# dtype: float64
# ----
# Country
# Western Sahara    0.0
# dtype: float64
# Country
# Western Sahara    0.0
# dtype: float64
# ----
# Country
# Palau    0.0
# dtype: float64
# Country
# Palau    0.0
# dtype: float64
# ----

# %% [markdown]
# Q5. Plot the bubble plot for Norway, Denmark, Finland

# %%
df = df_can.loc[['Norway','Denmark', 'Finland'], years].transpose()
df.reset_index(inplace=True)
df.index.name = 'index'
df.rename(columns={'index':'Year'}, inplace=True)

normnor = (df['Norway'] - df['Norway'].min()) / (df['Norway'].max() - df['Norway'].min())
normden = (df['Denmark'] - df['Denmark'].min()) / (df['Denmark'].max() - df['Denmark'].min())
normfin = (df['Finland'] - df['Finland'].min()) / (df['Finland'].max() - df['Finland'].min())


ax0 = df.plot(
    kind='scatter',
    figsize=(10,10),
    x='Year',
    y='Norway',
    color='blue',
    s = normnor*200
)

ax1 = df.plot(
    kind='scatter',
    figsize=(10,10),
    x='Year',
    y='Denmark',
    color='green',
    ax=ax0,
    s = normden*200
)
ax2 = df.plot(
    kind='scatter',
    figsize=(10,10),
    x='Year',
    y='Norway',
    color='red',
    ax=ax0,
    s = normfin*200
)


ax0.set_title("Norway, Denmark and Finland immigration to canada from 1980-2013")
ax0.set_xlabel("Years")
ax0.set_ylabel("Number of immigrants")
ax0.legend(['Norway', 'Denmark', 'Finland'], loc='upper right')

# %% [markdown]
# Waffle Charts
# :

# %%
# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches # needed for waffle Charts

mpl.style.use('ggplot') # optional: for ggplot-like style

# check for latest version of Matplotlib
print ('Matplotlib version: ', mpl.__version__) # >= 2.0.0
# Out:
# Matplotlib version:  3.2.2

# %%
def create_waffle_chart(categories, values, height, width, colormap, value_sign=''):

    # compute the proportion of each category with respect to the total
    total_values = sum(values)
    category_proportions = [(float(value) / total_values) for value in values]

    # compute the total number of tiles
    total_num_tiles = width * height # total number of tiles
    print ('Total number of tiles is', total_num_tiles)
    
    # compute the number of tiles for each catagory
    tiles_per_category = [round(proportion * total_num_tiles) for proportion in category_proportions]

    # print out number of tiles per category
    for i, tiles in enumerate(tiles_per_category):
        print (df_dsn.index.values[i] + ': ' + str(tiles))
    
    # initialize the waffle chart as an empty matrix
    waffle_chart = np.zeros((height, width))

    # define indices to loop through waffle chart
    category_index = 0
    tile_index = 0

    # populate the waffle chart
    for col in range(width):
        for row in range(height):
            tile_index += 1

            # if the number of tiles populated for the current category 
            # is equal to its corresponding allocated tiles...
            if tile_index > sum(tiles_per_category[0:category_index]):
                # ...proceed to the next category
                category_index += 1       
            
            # set the class value to an integer, which increases with class
            waffle_chart[row, col] = category_index
    
    # instantiate a new figure object
    fig = plt.figure()

    # use matshow to display the waffle chart
    colormap = plt.cm.coolwarm
    plt.matshow(waffle_chart, cmap=colormap)
    plt.colorbar()

    # get the axis
    ax = plt.gca()

    # set minor ticks
    ax.set_xticks(np.arange(-.5, (width), 1), minor=True)
    ax.set_yticks(np.arange(-.5, (height), 1), minor=True)
    
    # add dridlines based on minor ticks
    ax.grid(which='minor', color='w', linestyle='-', linewidth=2)

    plt.xticks([])
    plt.yticks([])

    # compute cumulative sum of individual categories to match color schemes between chart and legend
    values_cumsum = np.cumsum(values)
    total_values = values_cumsum[len(values_cumsum) - 1]

    # create legend
    legend_handles = []
    for i, category in enumerate(categories):
        if value_sign == '%':
            label_str = category + ' (' + str(values[i]) + value_sign + ')'
        else:
            label_str = category + ' (' + value_sign + str(values[i]) + ')'
            
        color_val = colormap(float(values_cumsum[i])/total_values)
        legend_handles.append(mpatches.Patch(color=color_val, label=label_str))

    # add legend to chart
    plt.legend(
        handles=legend_handles,
        loc='lower center', 
        ncol=len(categories),
        bbox_to_anchor=(0., -0.2, 0.95, .1)
    )

# %%
dfindopakchina = df_can.loc[['India', 'Pakistan', 'China'], :]

dfindopakchina
# Out:
#          Continent         Region             DevName  ...   2012   2013   Total
# Country                                                ...
# India         Asia  Southern Asia  Developing regions  ...  30933  33087  691904
# Pakistan      Asia  Southern Asia  Developing regions  ...  11227  12603  241600
# China         Asia   Eastern Asia  Developing regions  ...  33024  34129  659962
#
# [3 rows x 38 columns]

# %%
df_dsn = df_can.loc[['India', 'Pakistan', 'China'], :]

categories = df_dsn.index.values

value = df_dsn['Total']

#create a waffle chart

width=40
height=10

colormap = plt.cm.coolwarm

# %%
create_waffle_chart(categories, value, height, width, colormap)
# Out:
# Total number of tiles is 400
# India: 174
# Pakistan: 61
# China: 166

# %% [markdown]
# Word clouds

# %%
# !conda install -c conda-forge wordcloud==1.4.1 --yes

# import package and its set of stopwords
from wordcloud import WordCloud, STOPWORDS

print ('Wordcloud is installed and imported!')

# download file and save as alice_novel.txt
# !wget --quiet https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/alice_novel.txt

# open the file and read it into a variable alice_novel
alice_novel = open('alice_novel.txt', 'r').read()
    
print ('File downloaded and saved!')
# Out:
# /bin/bash: conda: command not found
# Wordcloud is installed and imported!
# File downloaded and saved!

# %%
#step1 - preprocessing

stopwordsrem = set(STOPWORDS)

#step 2-wordcloud object

alicewc = WordCloud(
    background_color = 'white',
    max_words = 2000,
    stopwords = stopwordsrem
)


#step3 - use the object to call function

alicewc.generate(alice_novel)

# step 4 - display

plt.imshow(alicewc)
plt.show()

# %%
#step1 - preprocessing

stopwordsrem = set(STOPWORDS)
stopwordsrem.add('said')


#step 2-wordcloud object

alicewc = WordCloud(
    background_color = 'white',
    max_words = 2000,
    stopwords = stopwordsrem
)


#step3 - use the object to call function

alicewc.generate(alice_novel)

# step 4 - display
fig = plt.figure()
fig.set_figwidth(20)
fig.set_figheight(20)
plt.imshow(alicewc)
plt.axis('off')
plt.show()

# %% [markdown]
# Maps

# %%
import numpy as np

import pandas as pd

import folium

# %%
map1 = folium.Map()
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map2 = folium.Map(location=[37.22, -122.16], zoom_start=12)
map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map3 = folium.Map(location=[56.130, -106.35], zoom_start=10, tiles='Stamen Toner')
map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map4 = folium.Map(location=[56.130, -106.35], zoom_start=5, tiles='Stamen Terrain')
map4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Find coordinates of mumbai and plot on maps
mumbai = folium.Map(location=[19.0760, 72.877], zoom_start=12)
mumbai
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df_incidents = pd.read_csv('https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/Police_Department_Incidents_-_Previous_Year__2016_.csv')

print('Dataset downloaded and read into a pandas dataframe!')

df_incidents.head()

df_incidents.shape
# Out:
# Dataset downloaded and read into a pandas dataframe!
# (150500, 13)

# %% [markdown]
# Markers with maps

# %%
#step1 - obtain dataset
df1 = df_incidents.iloc[0:100,:]

#step 2 - map
lat = 37.77
longs = -122.42

map1 = folium.Map(location=[lat, longs], zoom_start=12)


for lat, longs, labels in zip(df1.Y, df1.X, df1.Category):
  folium.CircleMarker(
      [lat, longs],
      radius=5,
      color='yellow',
      fill=True,
      popup=labels,
      fill_color='blue',
      fill_opacity=0.6
  ).add_to(map1)

map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df1 = df_incidents.iloc[0:100,:]

#step 2 - map
lat = 37.77
longs = -122.42

map1 = folium.Map(location=[lat, longs], zoom_start=12)

#cluster
from folium import plugins
clust = plugins.MarkerCluster().add_to(map1)


for lat, longs, labels in zip(df1.Y, df1.X, df1.Category):
  folium.CircleMarker(
      [lat, longs],
      radius=5,
      color='yellow',
      fill=True,
      popup=labels,
      fill_color='blue',
      fill_opacity=0.6
  ).add_to(clust)

map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Choropleth map

# %%
df_can.reset_index(inplace=True)
# download countries geojson file
# !wget --quiet https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/world_countries.json -O world_countries.json
    
print('GeoJSON file downloaded!')
# Out:
# GeoJSON file downloaded!

# %%
worldmap = folium.Map(location=[0,0], zoom_start=2, tiles='Stamen Watercolor')
worldmap

world_geo = r'world_countries.json'

worldmap.choropleth(
    geo_data = world_geo,
    data=df_can,
    columns=['Country','Total'],
    key_on='feature.properties.name',
    legend='Immigration to Canada',
    fill_color='YlOrRd'
 )

worldmap
# Out:
# /usr/local/lib/python3.6/dist-packages/folium/folium.py:426: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   FutureWarning
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
worldmap = folium.Map(location=[0,0], zoom_start=2, tiles='Stamen Watercolor')
worldmap

world_geo = r'world_countries.json'


scale = np.linspace(df_can['Total'].min(), df_can['Total'].max(), 6, dtype=int)
scale = scale.tolist()
scale[-1] = scale[-1]+1

worldmap.choropleth(
    geo_data = world_geo,
    data=df_can,
    columns=['Country','Total'],
    key_on='feature.properties.name',
    legend='Immigration to Canada',
    fill_color='YlOrRd',
    threshold_scale=scale
 )

worldmap
# Out:
# /usr/local/lib/python3.6/dist-packages/folium/folium.py:426: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   FutureWarning
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
